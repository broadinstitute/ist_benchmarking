# %%
import sys
import os
import numpy as np
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
from scipy.ndimage.morphology import binary_dilation
from matplotlib_scalebar.scalebar import ScaleBar
import matplotlib.pyplot as plt
from skimage.io import imread
from skimage.segmentation import find_boundaries

sys.path.append('../src/')
from st_utils import imshow, df_2_gdf, sim_overlay, vectorize
from constants import SAMPLES, PIXEL_TO_UM, seg_cmap

import warnings
if not sys.warnoptions:
    warnings.simplefilter("ignore")
# Out:
# /tmp/ipykernel_2818/91316530.py:7: DeprecationWarning: Please use `binary_dilation` from the `scipy.ndimage` namespace, the `scipy.ndimage.morphology` namespace is deprecated.
#   from scipy.ndimage.morphology import binary_dilation

# %%
sample = '2024_cosmx_multitissue_htma'

folder = f'data/{sample}/segmentation_by_fov_parquet'
if not os.path.exists(folder):
    os.makedirs(folder)

for fov in range(1,151):
    fov = str(fov).zfill(3)
    filename = f'data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV{fov}/CellLabels_F{fov}.tif'
    try:
        print (filename)
        img = imread(filename)
        img_boundary = find_boundaries(img, connectivity=1, mode='outer').astype(int)
        gdf = vectorize(img_boundary)
        gdf.to_parquet(f'{folder}/FOV_{fov}.parquet.gzip', compression='gzip')
    except:
        continue
# Out:
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV001/CellLabels_F001.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV002/CellLabels_F002.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV003/CellLabels_F003.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV004/CellLabels_F004.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV005/CellLabels_F005.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV006/CellLabels_F006.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV007/CellLabels_F007.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV008/CellLabels_F008.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV009/CellLabels_F009.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV010/CellLabels_F010.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV011/CellLabels_F011.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV012/CellLabels_F012.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV013/CellLabels_F013.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV014/CellLabels_F014.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV015/CellLabels_F015.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV016/CellLabels_F016.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV017/CellLabels_F017.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV018/CellLabels_F018.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV019/CellLabels_F019.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV020/CellLabels_F020.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV021/CellLabels_F021.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV022/CellLabels_F022.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV023/CellLabels_F023.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV024/CellLabels_F024.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV025/CellLabels_F025.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV026/CellLabels_F026.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV027/CellLabels_F027.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV028/CellLabels_F028.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV029/CellLabels_F029.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV030/CellLabels_F030.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV031/CellLabels_F031.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV032/CellLabels_F032.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV033/CellLabels_F033.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV034/CellLabels_F034.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV035/CellLabels_F035.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV036/CellLabels_F036.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV037/CellLabels_F037.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV038/CellLabels_F038.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV039/CellLabels_F039.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV040/CellLabels_F040.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV041/CellLabels_F041.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV042/CellLabels_F042.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV043/CellLabels_F043.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV044/CellLabels_F044.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV045/CellLabels_F045.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV046/CellLabels_F046.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV047/CellLabels_F047.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV048/CellLabels_F048.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV049/CellLabels_F049.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV050/CellLabels_F050.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV051/CellLabels_F051.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV052/CellLabels_F052.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV053/CellLabels_F053.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV054/CellLabels_F054.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV055/CellLabels_F055.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV056/CellLabels_F056.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV057/CellLabels_F057.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV058/CellLabels_F058.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV059/CellLabels_F059.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV060/CellLabels_F060.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV061/CellLabels_F061.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV062/CellLabels_F062.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV063/CellLabels_F063.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV064/CellLabels_F064.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV065/CellLabels_F065.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV066/CellLabels_F066.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV067/CellLabels_F067.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV068/CellLabels_F068.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV069/CellLabels_F069.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV070/CellLabels_F070.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV071/CellLabels_F071.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV072/CellLabels_F072.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV073/CellLabels_F073.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV074/CellLabels_F074.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV075/CellLabels_F075.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV076/CellLabels_F076.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV077/CellLabels_F077.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV078/CellLabels_F078.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV079/CellLabels_F079.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV080/CellLabels_F080.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV081/CellLabels_F081.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV082/CellLabels_F082.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV083/CellLabels_F083.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV084/CellLabels_F084.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV085/CellLabels_F085.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV086/CellLabels_F086.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV087/CellLabels_F087.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV088/CellLabels_F088.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV089/CellLabels_F089.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV090/CellLabels_F090.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV091/CellLabels_F091.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV092/CellLabels_F092.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV093/CellLabels_F093.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV094/CellLabels_F094.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV095/CellLabels_F095.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV096/CellLabels_F096.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV097/CellLabels_F097.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV098/CellLabels_F098.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV099/CellLabels_F099.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV100/CellLabels_F100.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV101/CellLabels_F101.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV102/CellLabels_F102.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV103/CellLabels_F103.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV104/CellLabels_F104.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV105/CellLabels_F105.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV106/CellLabels_F106.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV107/CellLabels_F107.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV108/CellLabels_F108.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV109/CellLabels_F109.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV110/CellLabels_F110.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV111/CellLabels_F111.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV112/CellLabels_F112.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV113/CellLabels_F113.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV114/CellLabels_F114.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV115/CellLabels_F115.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV116/CellLabels_F116.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV117/CellLabels_F117.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV118/CellLabels_F118.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV119/CellLabels_F119.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV120/CellLabels_F120.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV121/CellLabels_F121.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV122/CellLabels_F122.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV123/CellLabels_F123.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV124/CellLabels_F124.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV125/CellLabels_F125.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV126/CellLabels_F126.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV127/CellLabels_F127.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV128/CellLabels_F128.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV129/CellLabels_F129.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV130/CellLabels_F130.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV131/CellLabels_F131.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV132/CellLabels_F132.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV133/CellLabels_F133.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV134/CellLabels_F134.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV135/CellLabels_F135.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV136/CellLabels_F136.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV137/CellLabels_F137.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV138/CellLabels_F138.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV139/CellLabels_F139.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV140/CellLabels_F140.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV141/CellLabels_F141.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV142/CellLabels_F142.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV143/CellLabels_F143.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV144/CellLabels_F144.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV145/CellLabels_F145.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV146/CellLabels_F146.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV147/CellLabels_F147.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV148/CellLabels_F148.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV149/CellLabels_F149.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/CellStatsDir/FOV150/CellLabels_F150.tif

# %%
sample = '2024_cosmx_multitissue_tumor2'

folder = f'data/{sample}/segmentation_by_fov_parquet'
if not os.path.exists(folder):
    os.makedirs(folder)

for fov in range(110,177):
    fov = str(fov).zfill(3)
    filename = f'data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV{fov}/CellLabels_F{fov}.tif'
    try:
        print (filename)
        img = imread(filename)
        img_boundary = find_boundaries(img, connectivity=1, mode='outer').astype(int)
        gdf = vectorize(img_boundary)
        gdf.to_parquet(f'{folder}/FOV_{fov}.parquet.gzip', compression='gzip')
    except:
        continue
# Out:
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV110/CellLabels_F110.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV111/CellLabels_F111.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV112/CellLabels_F112.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV113/CellLabels_F113.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV114/CellLabels_F114.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV115/CellLabels_F115.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV116/CellLabels_F116.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV117/CellLabels_F117.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV118/CellLabels_F118.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV119/CellLabels_F119.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV120/CellLabels_F120.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV121/CellLabels_F121.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV122/CellLabels_F122.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV123/CellLabels_F123.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV124/CellLabels_F124.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV125/CellLabels_F125.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV126/CellLabels_F126.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV127/CellLabels_F127.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV128/CellLabels_F128.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV129/CellLabels_F129.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV130/CellLabels_F130.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV131/CellLabels_F131.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV132/CellLabels_F132.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV133/CellLabels_F133.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV134/CellLabels_F134.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV135/CellLabels_F135.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV136/CellLabels_F136.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV137/CellLabels_F137.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV138/CellLabels_F138.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV139/CellLabels_F139.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV140/CellLabels_F140.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV141/CellLabels_F141.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV142/CellLabels_F142.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV143/CellLabels_F143.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV144/CellLabels_F144.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV145/CellLabels_F145.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV146/CellLabels_F146.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV147/CellLabels_F147.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV148/CellLabels_F148.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV149/CellLabels_F149.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV150/CellLabels_F150.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV151/CellLabels_F151.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV152/CellLabels_F152.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV153/CellLabels_F153.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV154/CellLabels_F154.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV155/CellLabels_F155.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV156/CellLabels_F156.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV157/CellLabels_F157.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV158/CellLabels_F158.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV159/CellLabels_F159.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV160/CellLabels_F160.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV161/CellLabels_F161.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV162/CellLabels_F162.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV163/CellLabels_F163.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV164/CellLabels_F164.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV165/CellLabels_F165.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV166/CellLabels_F166.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV167/CellLabels_F167.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV168/CellLabels_F168.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV169/CellLabels_F169.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV170/CellLabels_F170.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV171/CellLabels_F171.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV172/CellLabels_F172.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV173/CellLabels_F173.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV174/CellLabels_F174.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV175/CellLabels_F175.tif
# data/cosmx/huan_tma_5724/20240430_BWH_TMA2/20240430_203348_S2/CellStatsDir/FOV176/CellLabels_F176.tif

# %%
import glob
import os

# Set the data directory path
data_dir = 'data/cosmx/huan_tma_5724/20240430_BWH_TMA_1/20240430_203348_S1/'

# Use glob to find files that end with 'parquet.gzip'
# The '**' pattern means this will recursively search all subdirectories
file_pattern = os.path.join(data_dir, '**', '*.parquet.gzip')
file_list = glob.glob(file_pattern, recursive=True)

# Print the list of files found
for file in file_list:
    print(file)

# %%
def get_data(sample, agg_unit_value, original_data_bucket, processed_data_bucket, download_dapi=True, download_mask=True, mask_compartment='nuc'):

    if 'xenium' in sample:

        if download_dapi:
            folder = f'data/{sample}/dapi_by_core'
            if not os.path.exists(folder):
                os.makedirs(folder)

            if os.path.isfile(f'{folder}/{agg_unit_value}.tif'):
                print (f'{folder}/{agg_unit_value}.tif is downloaded.')
            else:
                cmd = f'gsutil cp gs://{processed_data_bucket}/{sample}/morphology_focus_by_core/{agg_unit_value}.tif {folder}'
                ! {cmd}

        if download_mask:
            folder = f'data/{sample}/{mask_compartment}_segmentation_by_core'
            if not os.path.exists(folder):
                os.makedirs(folder)

            if os.path.isfile(f'{folder}/{agg_unit_value}.tif'):
                print (f'{folder}/{agg_unit_value}.tif is downloaded.')
            else:
                cmd = f'gsutil cp gs://{processed_data_bucket}/{sample}/{mask_compartment}_segmentation_by_core/{agg_unit_value}.tif {folder}'
                ! {cmd}
                
    elif 'cosmx' in sample:

        df_c =pd.read_parquet(f'data/cell_level_csv/{sample}_cell_level.parquet.gzip',
                    engine='pyarrow')[['cell_id','core','tissue_type','slide_ID_numeric','fov']]

        df_c['fov'] = df_c['fov'].apply(lambda x: str(x).zfill(3))
        fovs = df_c.loc[df_c['core'].isin(agg_unit_value)].fov.unique().tolist()
        print (fovs)

        for fov in fovs:
            if download_dapi:
                folder = f'data/{sample}/dapi_by_fov'
                if not os.path.exists(folder):
                    os.makedirs(folder)

                # if os.path.isfile(f'{folder}/CellComposite_F{fov}.jpg'):
                #     print (f'{folder}/CellComposite_F{fov}.jpg is downloaded.')
                else:
                    cmd = f'gsutil cp gs://{original_data_bucket}/CellOverlay/CellOverlay_F{fov}.jpg {folder}'
                    ! {cmd}

            if download_mask:

                # Parquet
                folder = f'data/{sample}/segmentation_by_fov_parquet'
                if not os.path.exists(folder):
                    os.makedirs(folder)

                if os.path.isfile(f'{folder}/FOV_{fov}.parquet.gzip'):
                    print (f'{folder}/FOV_{fov}.parquet.gzip is downloaded.')
                else:
                    cmd = f'gsutil cp gs://{processed_data_bucket}/{sample}/cell_boundaries_by_fov/FOV_{fov}.parquet.gzip {folder}'
                    ! {cmd}

                # Image
                folder = f'data/{sample}/segmentation_by_fov_image'
                if not os.path.exists(folder):
                    os.makedirs(folder)

                if os.path.isfile(f'{folder}/CellLabels_F{fov}.tif'):
                    print (f'{folder}/CellLabels_F{fov}.tif is downloaded.')
                else:
                    cmd = f'gsutil cp gs://{original_data_bucket}/FOV{fov}/CellLabels_F{fov}.tif {folder}'
                    ! {cmd}

        cmd = f'gsutil cp gs://{processed_data_bucket}/{sample}/latest.fovs.csv data/{sample}'
        ! {cmd}

    elif 'merscope' in sample:

        if download_dapi:
            folder = f'data/{sample}/dapi_by_core'
            if not os.path.exists(folder):
                os.makedirs(folder)

            if os.path.isfile(f'{folder}/{agg_unit_value}.tif'):
                print (f'{folder}/{agg_unit_value}.tif is downloaded.')
            else:
                cmd = f'gsutil cp gs://{processed_data_bucket}/{sample}/dapi_by_core/{agg_unit_value}.tif {folder}'
                ! {cmd}

        # if download_mask:
        #     print ('not supported yet')
        #     folder = f'data/{sample}/region_{agg_unit_value}'
        #     if not os.path.exists(folder):
        #         os.makedirs(folder)

        #     if os.path.isfile(f'{folder}/region_{agg_unit_value}.tif'):
        #         print (f'{folder}/cell_boundaries.parquet is downloaded.')
        #     else:
        #         cmd = f"gsutil cp gs://{original_data_bucket}/region_{agg_unit_value}/cell_boundaries.parquet {folder}/cell_boundaries.parquet'"
        #         ! {cmd}
             
def remove_data(sample, core):
    for folder in [f'data/{sample}/dapi_by_core', 
                   f'data/{sample}/nuc_segmentation_by_core',
                   f'data/{sample}/cell_segmentation_by_core',
                   f'data/{sample}/segmentation_by_fov_parquet']:
        os.remove(f"{folder}/{core}.tif")

def thicker_boundary(img_boundary, iterations=2):

    # Define the structuring element for dilation (e.g., a 3x3 square)
    structuring_element = np.array([[1, 1, 1],
                                    [1, 1, 1],
                                    [1, 1, 1]])

    # Apply binary dilation to make the mask thicker
    thicker_mask = binary_dilation(img_boundary, structure=structuring_element, iterations=iterations)

    return thicker_mask

# %% [markdown]
# # XENIUM

# %%
### HTMA
processed_data_bucket = 'fc-b8e703d3-de2d-4532-94cc-efe864b4feea/SPARC/processed_data/data'
cores = [109] # 136, 98, 56
SAMPS = SAMPLES[::2]

# ### Normal
# processed_data_bucket = 'fc-b8e703d3-de2d-4532-94cc-efe864b4feea/SPARC/processed_data/data'
# cores = [18]
# SAMPS = SAMPLES[1::2]

left_corner = False
sample = '2024_xenium_breast_htma'
scale_bar = ScaleBar(PIXEL_TO_UM[sample.split('_')[-3]], "um", 
                            color='white', box_color='grey', box_alpha=0.9, 
                            location='upper left', font_properties={'size':30})

for core in cores:
    get_data(sample, core, '', processed_data_bucket, download_dapi=True, download_mask=True, mask_compartment='cell')

    img_mask = imread(f'data/{sample}/cell_segmentation_by_core/{core}.tif')
    img_dapi = imread(f'data/{sample}/dapi_by_core/{core}.tif')

    img_mask = np.flipud(img_mask)
    img_dapi = np.flipud(img_dapi)

    x_mid = int(img_mask.shape[0]/2)
    y_mid = int(img_mask.shape[1]/2)

    for ratio in [0.25]:
        print (f'{sample}, core:{core}, ratio:{ratio}')
        r = int(x_mid * ratio)

        if left_corner:
            subset_dapi = img_dapi[0:2*r, y_mid-r:y_mid+r]
            subset_mask = img_mask[0:2*r, y_mid-r:y_mid+r]
        else:
            subset_dapi = img_dapi[x_mid-r:x_mid+r, y_mid-r:y_mid+r]
            subset_mask = img_mask[x_mid-r:x_mid+r, y_mid-r:y_mid+r]

        gdf_subset_mask = vectorize(subset_mask)
        sim_overlay(subset_dapi, gdf_subset_mask, 10, 0.01, 0.98, seg_cmap, scale_bar, xy_range=False, lw=1, save=True, fname=f'figures/Fig_4_Segmentation/Main_Fig_4_A_DAPI_{core}_{sample}.png')

    # remove_data(sample, core)
# Out:
# data/2024_xenium_breast_htma/dapi_by_core/109.tif is downloaded.
# CommandException: No URLs matched: gs://fc-b8e703d3-de2d-4532-94cc-efe864b4feea/SPARC/processed_data/data/2024_xenium_breast_htma/cell_segmentation_by_core/109.tif
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[21], line 20
#      17 for core in cores:
#      18     get_data(sample, core, '', processed_data_bucket, download_dapi=True, download_mask=True, mask_compartment='cell')
# ---> 20     img_mask = imread(f'data/{sample}/cell_segmentation_by_core/{core}.tif')
#      21     img_dapi = imread(f'data/{sample}/dapi_by_core/{core}.tif')
#      23     img_mask = np.flipud(img_mask)
#
# File ~/anaconda3/envs/sp/lib/python3.8/site-packages/skimage/io/_io.py:53, in imread(fname, as_gray, plugin, **plugin_args)
#      50         plugin = 'tifffile'
#      52 with file_or_url_context(fname) as fname:
# ---> 53     img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#      55 if not hasattr(img, 'ndim'):
#      56     return img
#
# File ~/anaconda3/envs/sp/lib/python3.8/site-packages/skimage/io/manage_plugins.py:205, in call_plugin(kind, *args, **kwargs)
#     202     except IndexError:
#     203         raise RuntimeError(f'Could not find the plugin "{plugin}" for {kind}.')
# --> 205 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/sp/lib/python3.8/site-packages/skimage/io/_plugins/tifffile_plugin.py:74, in imread(fname, **kwargs)
#      71 if 'img_num' in kwargs:
#      72     kwargs['key'] = kwargs.pop('img_num')
# ---> 74 return tifffile_imread(fname, **kwargs)
#
# File ~/anaconda3/envs/sp/lib/python3.8/site-packages/tifffile/tifffile.py:1053, in imread(files, aszarr, key, series, level, squeeze, maxworkers, mode, name, offset, size, pattern, axesorder, categories, imread, sort, container, chunkshape, dtype, axestiled, ioworkers, chunkmode, fillvalue, zattrs, multiscales, omexml, out, out_inplace, _multifile, _useframes, **kwargs)
#    1048     files = files[0]
#    1050 if isinstance(files, str) or not isinstance(
#    1051     files, collections.abc.Sequence
#    1052 ):
# -> 1053     with TiffFile(
#    1054         files,
#    1055         mode=mode,
#    1056         name=name,
#    1057         offset=offset,
#    1058         size=size,
#    1059         omexml=omexml,
#    1060         _multifile=_multifile,
#    1061         _useframes=_useframes,
#    1062         **is_flags,
#    1063     ) as tif:
#    1064         if aszarr:
#    1065             assert key is None or isinstance(key, int)
#
# File ~/anaconda3/envs/sp/lib/python3.8/site-packages/tifffile/tifffile.py:3965, in TiffFile.__init__(self, file, mode, name, offset, size, omexml, _multifile, _useframes, _parent, **is_flags)
#    3962 if mode not in (None, 'r', 'r+', 'rb', 'r+b'):
#    3963     raise ValueError(f'invalid mode {mode!r}')
# -> 3965 fh = FileHandle(file, mode=mode, name=name, offset=offset, size=size)
#    3966 self._fh = fh
#    3967 self._multifile = True if _multifile is None else bool(_multifile)
#
# File ~/anaconda3/envs/sp/lib/python3.8/site-packages/tifffile/tifffile.py:13845, in FileHandle.__init__(self, file, mode, name, offset, size)
#   13843 self._close = True
#   13844 self._lock = NullContext()
# > 13845 self.open()
#   13846 assert self._fh is not None
#
# File ~/anaconda3/envs/sp/lib/python3.8/site-packages/tifffile/tifffile.py:13860, in FileHandle.open(self)
#   13858 self._file = os.path.realpath(self._file)
#   13859 self._dir, self._name = os.path.split(self._file)
# > 13860 self._fh = open(self._file, self._mode)  # type: ignore
#   13861 self._close = True
#   13862 if self._offset < 0:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/disks/store/ist_benchmarking/data/2024_xenium_breast_htma/cell_segmentation_by_core/109.tif'

# %% [markdown]
# ## MERSCOPE trying

# %%
### HTMA
core = [109]

left_corner = False
sample = '2024_merscope_breast_htma'
scale_bar = ScaleBar(PIXEL_TO_UM[sample.split('_')[-3]], "um", 
                            color='white', box_color='grey', box_alpha=0.9, 
                            location='upper left', font_properties={'size':30})

for core in cores:
    get_data(sample, core, '', processed_data_bucket, download_dapi=True, download_mask=True, mask_compartment='cell')

    img_mask = imread(f'data/{sample}/cell_segmentation_by_core/{core}.tif')
    img_dapi = imread(f'data/{sample}/dapi_by_core/{core}.tif')

    img_mask = np.flipud(img_mask)
    img_dapi = np.flipud(img_dapi)

    x_mid = int(img_mask.shape[0]/2)
    y_mid = int(img_mask.shape[1]/2)

    for ratio in [0.25]:
        print (f'{sample}, core:{core}, ratio:{ratio}')
        r = int(x_mid * ratio)

        if left_corner:
            subset_dapi = img_dapi[0:2*r, y_mid-r:y_mid+r]
            subset_mask = img_mask[0:2*r, y_mid-r:y_mid+r]
        else:
            subset_dapi = img_dapi[x_mid-r:x_mid+r, y_mid-r:y_mid+r]
            subset_mask = img_mask[x_mid-r:x_mid+r, y_mid-r:y_mid+r]

        gdf_subset_mask = vectorize(subset_mask)
        sim_overlay(subset_dapi, gdf_subset_mask, 10, 0.01, 0.98, seg_cmap, scale_bar, xy_range=False, lw=1, save=True, fname=f'figures/Fig_4_Segmentation/Main_Fig_4_A_DAPI_{core}_{sample}.png')

    # remove_data(sample, core)

# %% [markdown]
# # MERSCOPE - get it from VM (get_dapi.ipynb)

# %% [markdown]
# # CosMx

# %%
# Select core to get the corresponding FOVs
# Then move to VM to create retrive segmentation mask, computing is needed.
cores = ['31']
sample = 'cosmx_multitissue_htma'
original_data_bucket = 'fc-b8e703d3-de2d-4532-94cc-efe864b4feea/SPARC/CosMX/cosmx_20231110_export/farhi_full_11723/htma/20230618_015734_S3/CellStatsDir'
processed_data_bucket = 'fc-b8e703d3-de2d-4532-94cc-efe864b4feea/SPARC/processed_data/data'

# Get segmentation mask from google bucket
get_data(sample, cores, original_data_bucket, processed_data_bucket, download_dapi = True, download_mask = True)

cores = [str(x) for x in cores]
# sample = SAMPS[-1]
df_c =pd.read_parquet(f'data/cell_level_csv/{sample}_cell_level.parquet.gzip',
                      engine='pyarrow')[['cell_id','core','tissue_type','slide_ID_numeric','fov']]

df_c['fov'] = df_c['fov'].apply(lambda x: str(x).zfill(3))

df_fovs = df_c.loc[df_c['core'].isin(cores)][['core','tissue_type','fov']].drop_duplicates().reset_index(drop=True)


# Plot
left_corner = False
scale_bar = ScaleBar(PIXEL_TO_UM[sample.split('_')[0]], "um", 
                            color='white', box_color='grey', box_alpha=0.9, 
                            location='upper left', font_properties={'size':30})

for i in range(len(df_fovs)):
    C = df_fovs.core[i]
    fov = df_fovs.fov[i]
    tt = df_fovs.tissue_type[i]
    print (C, fov, tt)

    # try:
    img_mask = imread(f'data/{sample}/segmentation_by_fov_image/CellLabels_F{fov}.tif')
    img_dapi = imread(f'data/{sample}/dapi_by_fov/CellOverlay_F{fov}.jpg')[...,0]

    img_mask = np.fliplr(np.rot90(img_mask,1))
    img_dapi = np.fliplr(np.rot90(img_dapi,1))

    x_mid = int(img_mask.shape[0]/2)
    y_mid = int(img_mask.shape[1]/2)

    for ratio in [0.4]:
        print (f'{sample}, core:{core}, ratio:{ratio}')
        r = int(x_mid * ratio)

        if left_corner:
            subset_dapi = img_dapi[0:2*r, y_mid-r:y_mid+r]
            subset_mask = img_mask[0:2*r, y_mid-r:y_mid+r]
        else:
            subset_dapi = img_dapi[x_mid-r:x_mid+r, y_mid-r:y_mid+r]
            subset_mask = img_mask[x_mid-r:x_mid+r, y_mid-r:y_mid+r]

        gdf_subset_mask = vectorize(subset_mask)
        sim_overlay(subset_dapi, gdf_subset_mask, 10, 0.01, 0.98, seg_cmap, scale_bar, xy_range=False, lw=1, save=True, fname=f'figures/Fig_4_Segmentation/Main_Fig_4_A_DAPI_{core}_{sample}.png')
# Out:
# ['130']
# Copying gs://fc-b8e703d3-de2d-4532-94cc-efe864b4feea/SPARC/CosMX/cosmx_20231110_export/farhi_full_11723/htma/20230618_015734_S3/CellStatsDir/CellOverlay/CellOverlay_F130.jpg...
# - [1 files][  7.4 MiB/  7.4 MiB]
# Operation completed over 1 objects/7.4 MiB.
# data/cosmx_multitissue_htma/segmentation_by_fov_parquet/FOV_130.parquet.gzip is downloaded.
# data/cosmx_multitissue_htma/segmentation_by_fov_image/CellLabels_F130.tif is downloaded.
# Copying gs://fc-b8e703d3-de2d-4532-94cc-efe864b4feea/SPARC/processed_data/data/cosmx_multitissue_htma/latest.fovs.csv...
# / [1 files][  8.7 KiB/  8.7 KiB]
# Operation completed over 1 objects/8.7 KiB.
# 31 130 CRC
# cosmx_multitissue_htma, core:31, ratio:0.4
